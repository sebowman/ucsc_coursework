# %%
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('/Users/sarahbowman/Downloads/hw4_2a_query.csv')

# %%
df
# Out:
#                source_id          ra  ra_error        dec  dec_error  \
# 0     598691984069077248  132.945370  0.601027  11.258305   0.436349
# 1     598690369158191872  132.912227  0.084070  11.225536   0.049075
# 2     598691228155046016  133.025408  0.906173  11.228774   0.613882
# 3     598692190224359808  132.925903  1.373622  11.272759   0.985739
# 4     598695660556715136  132.942568  0.777448  11.318312   0.544164
# 5     598694153022786432  132.793285  1.061320  11.265985   0.681628
# 6     598690059919347328  132.827200  0.442265  11.206799   0.239202
# 7     598687586022093952  132.683794  0.891460  11.194832   0.522486
# 8     598686971837692416  132.773470  0.281025  11.174523   0.170666
# 9     598688930342564224  132.896944  1.309537  11.169345   0.915923
# 10    598694767207638272  132.818986  1.143645  11.308134   0.733095
# 11    598689922484515584  132.811529  0.678070  11.191664   0.368325
# 12    598692774338692992  132.990007  1.306852  11.328643   1.047437
# ...

# %%
list(df.columns.values)
# Out:
# ['source_id',
#  'ra',
#  'ra_error',
#  'dec',
#  'dec_error',
#  'parallax',
#  'parallax_error',
#  'phot_g_mean_mag',
#  'bp_rp',
#  'radial_velocity',
#  'radial_velocity_error',
#  'phot_variable_flag',
#  'teff_val',
#  'a_g_val']

# %%
br = df.bp_rp
p = df.parallax
g = df.phot_g_mean_mag
ag = df.a_g_val
#ebr = df.e_bp_min_rp_val #etc
temp = df.teff_val

# %%
plt.hist(p,1000)
plt.xlim(0.5,2.5)
plt.xlabel("Parallax (mas)")
plt.ylabel('# of stars')
plt.axvline(x=1.056, color = 'red')
plt.axvline(x=1.213, color = 'red')
print 1/1.195 , 1/1.056
plt.title('Histogram of Parallaxes (region of overdensity highlighted in red)')
#plt.savefig('hw4plot1')
# Out:
# 0.836820083682 0.94696969697

# %%
plt.hist(p,155)
#plt.xlim(0,2.5)
# Out:
# (array([  5.37000000e+02,   5.15000000e+02,   4.93000000e+02,
#           5.08000000e+02,   1.08500000e+03,   5.21000000e+02,
#           2.76000000e+02,   2.23000000e+02,   1.87000000e+02,
#           1.47000000e+02,   1.35000000e+02,   9.40000000e+01,
#           1.13000000e+02,   9.40000000e+01,   6.80000000e+01,
#           5.80000000e+01,   5.70000000e+01,   5.00000000e+01,
#           4.10000000e+01,   3.70000000e+01,   2.10000000e+01,
#           3.30000000e+01,   2.00000000e+01,   2.30000000e+01,
#           2.10000000e+01,   2.10000000e+01,   1.50000000e+01,
#           8.00000000e+00,   7.00000000e+00,   1.20000000e+01,
#           6.00000000e+00,   1.00000000e+01,   5.00000000e+00,
#           7.00000000e+00,   6.00000000e+00,   3.00000000e+00,
#           1.00000000e+01,   8.00000000e+00,   4.00000000e+00,
#           3.00000000e+00,   1.00000000e+00,   5.00000000e+00,
#           3.00000000e+00,   1.00000000e+00,   0.00000000e+00,
# ...
