# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from astropy.io import ascii

# %%
history01 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass01/LOGS/history.data',header_start=4,data_start=5)
history025 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass025/LOGS/history.data',header_start=4,data_start=5)
history05 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass05/LOGS/history.data',header_start=4,data_start=5)
history1 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass1/LOGS/history.data',header_start=4,data_start=5)

names = history1.colnames
print names

plt.figure(figsize=(10,6))
plt.plot(10**(history01['log_Teff']), history01['log_L'] , '.', color='indigo',label='0.1 $M_{\odot}$ star')
plt.plot(10**(history025['log_Teff']), history025['log_L'] , '.',label='0.25 $M_{\odot}$ star')
plt.plot(10**(history05['log_Teff']), history05['log_L'] , '.',color='green',label='0.5 $M_{\odot}$ star')
plt.plot(10**(history1['log_Teff']), history1['log_L'] , '.',color='deepskyblue',label='1 $M_{\odot}$ star')

plt.title('HR diagram (until ZAMS)')
plt.legend(title = 'Solid lines are Hayashi tracks', loc='best')
plt.xlim(6000,2500)
plt.xlabel('T')
plt.ylabel('logL')

#plt.savefig('hw3p4plot.pdf')
# Out:
# ['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass', 'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top', 'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot', 'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp', 'cno', 'tri_alfa', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3', 'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8', 'he_core_mass', 'c_core_mass', 'o_core_mass', 'si_core_mass', 'fe_core_mass', 'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g', 'v_div_csound_surf', 'log_center_T', 'log_center_Rho', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T', 'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4', 'center_c12', 'center_o16', 'surface_c12', 'surface_o16', 'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_backups', 'num_iters']

# %%
print 10**(history1['log_Teff'])[1:20]
# Out:
#    log_Teff
# -------------
# 4302.72902135
# 4260.47069188
# 4185.19100238
# 4081.69095752
# 3978.36684628
# 3901.06485926
# 3857.37553855
# 3838.76006165
# 3833.31200938
# 3832.27753699
# 3832.23478506
# 3832.47608641
# 3833.10089843
# 3834.64472555
#   3838.384719
# 3847.09303949
# 3859.84547911
# 3873.05722903
# 3886.00229193

# %%
history02 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass05_inity02/LOGS/history.data',header_start=4,data_start=5)
history04 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass05_inity04/LOGS/history.data',header_start=4,data_start=5)
history06 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass05_inity06/LOGS/history.data',header_start=4,data_start=5)
history08 = ascii.read('/Users/sarahbowman/Desktop/mesa-r10398/mass05_inity08/LOGS/history.data',header_start=4,data_start=5)

names = history1.colnames
print names

plt.figure(figsize=(10,6))
plt.plot(10**(history02['log_Teff']), history02['log_L'] ,'.', color='indigo',label='Initial Y = 0.2')
plt.plot(10**(history04['log_Teff']), history04['log_L'] ,'.', label='Initial Y = 0.4')
plt.plot(10**(history06['log_Teff']), history06['log_L'] ,'.', color='green',label='Initial Y = 0.6')
plt.plot(10**(history08['log_Teff']), history08['log_L'] ,'.', color='deepskyblue',label='Initial Y = 0.8')

plt.title('HR diagram (until ZAMS) for a 0.5 $M_{\odot}$ star with varying initial He fraction')
plt.legend(title = 'Solid lines are Hayashi tracks',loc='best')
plt.xlim(8000,3500)
plt.xlabel('T')
plt.ylabel('logL')

#plt.savefig('hw3p4plot.pdf')
# Out:
# ['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass', 'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top', 'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot', 'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp', 'cno', 'tri_alfa', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3', 'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8', 'he_core_mass', 'c_core_mass', 'o_core_mass', 'si_core_mass', 'fe_core_mass', 'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g', 'v_div_csound_surf', 'log_center_T', 'log_center_Rho', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T', 'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4', 'center_c12', 'center_o16', 'surface_c12', 'surface_o16', 'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_backups', 'num_iters']

# %%
print 10**(history08['log_Teff'])[1:20]
# Out:
#    log_Teff
# -------------
# 4935.70454093
# 4880.54238285
# 4779.11260573
# 4634.66346405
# 4484.63138466
# 4369.43892373
# 4301.21792597
# 4272.01715568
# 4264.02238478
# 4262.50621185
# 4263.04358115
# 4265.15012432
# 4270.29890138
# 4282.61068796
# 4301.97581427
# 4322.01547861
# 4341.66979715
# 4361.47123844
# 4380.64809467

# %%
print len(profile05['logR'])
print len(dlnT)
print np.e**(profile05['logR'][-1])
np.max(profile05['logR'])
# Out:
# 759
# 758
# 0.0467914036327
# -0.35106875836849344

# %%
history1 = ascii.read('/Users/sarahbowman/Desktop/history1.data.txt',header_start=4,data_start=5)

history = history1

names = history.colnames

figure(figsize=(10,6))
plot(history['star_age'], history['log_R'])
semilogx()
title('Radius as a function of time for a 1 Solar Mass Star')
xlabel('age [yr]')
ylabel('log(Radius) [solar]')
grid()

savefig('1sm.pdf')

# %%
history8 = ascii.read('/Users/sarahbowman/Desktop/history8.data.txt',header_start=4,data_start=5)

history = history8

names = history.colnames

figure(figsize=(10,6))
plot(history['star_age'], history['log_R'], color='green')
semilogx()
title('Radius as a function of time for an 8 Solar Mass Star')
xlabel('age [yr]')
ylabel('log(Radius) [solar]')
grid()
savefig('8sm.pdf')

# %%
history128 = ascii.read('/Users/sarahbowman/Desktop/history128.data.txt',header_start=4,data_start=5)

history = history128

names = history.colnames

figure(figsize=(10,6))
plot(history['star_age'], history['log_R'], color='deepskyblue')
semilogx()
title('Radius as a function of time for a 128 Solar Mass Star')
xlabel('age [yr]')
ylabel('log(Radius) [solar]')
grid()
savefig('0128sm.pdf')

# %%
x = [0.5,1,8,128]
y = [history05['star_age'][-1],history1['star_age'][-1],history8['star_age'][-1],history128['star_age'][-1]]
figure(figsize=(10,6))
plot(x, y, 'o', color='m')
semilogy()
title('Time to reach the Main Sequence as a function of mass')
ylabel('age [yr]')
xlabel('mass [solar]')
grid()
savefig('tvsm.pdf')

# %%
print names
# Out:
# ['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass', 'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top', 'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot', 'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp', 'cno', 'tri_alfa', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3', 'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8', 'he_core_mass', 'c_core_mass', 'o_core_mass', 'si_core_mass', 'fe_core_mass', 'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g', 'v_div_csound_surf', 'log_center_T', 'log_center_Rho', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T', 'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4', 'center_c12', 'center_o16', 'surface_c12', 'surface_o16', 'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_backups', 'num_iters']

# %%
history05 = ascii.read('/Users/sarahbowman/Desktop/history0.5.data.txt',header_start=4,data_start=5)
history1 = ascii.read('/Users/sarahbowman/Desktop/history1.data.txt',header_start=4,data_start=5)
history8 = ascii.read('/Users/sarahbowman/Desktop/history8.data.txt',header_start=4,data_start=5)
history128 = ascii.read('/Users/sarahbowman/Desktop/history128.data.txt',header_start=4,data_start=5)

figure(figsize=(10,6))
plot(history05['star_age'], history05['log_R'],color='indigo',label='0.5 $M_{\odot}$ star')
plot(history1['star_age'], history1['log_R'],label='1 $M_{\odot}$ star')
plot(history8['star_age'], history8['log_R'],color='green',label='8 $M_{\odot}$ star')
plot(history128['star_age'], history128['log_R'],color='deepskyblue',label='128 $M_{\odot}$ star')
title('Radius as a function of time (until star reaches Main Sequence)')
legend()
semilogx()
xlabel('age [yr]')
ylabel('log(Radius) [solar]')
grid()

savefig('rvt.pdf')
